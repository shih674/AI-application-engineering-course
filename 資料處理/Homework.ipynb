# %%
import requests
import json
search_item = '錢包'
page = 1

url = f'https://ecshweb.pchome.com.tw/search/v3.3/all/results?q={search_item}&page=1&sort=sale/dc'

json_file = requests.get(url)
json_content = json.loads(json_file.text)
goods = json_content['prods']

# %%
goods
# Out:
# [{'Id': 'DIBMAR-A90095EBR',
#   'cateId': 'DIBMW2',
#   'picS': '/items/DIBMARA90095EBR/000002_1548301485.jpg',
#   'picB': '/items/DIBMARA90095EBR/000001_1548301485.jpg',
#   'name': 'KAKA 韓系簡約長夾 皮夾 手拿包 手機包 零錢包 長皮包',
#   'describe': 'KAKA 韓系簡約長夾 皮夾 手拿包 手機包 零錢包 長皮包 信用卡夾\\r\\n◆ 多夾層、大容量可裝入5.5吋手機\r\n◆ 鈔票位x3、卡片位x3、拉鍊袋x3、收據夾層x2\r\n◆ 耐磨布料，質感極佳\r\n◆ 拉鍊設計，使用方便\r\n◆ 超實搭配件\r\n\r\n  外觀尺寸  \r\n約高21cm，寬10cm，厚度2.5cm\r\n(尺寸皆為人工測量，可能有1-2cm的誤差)\r\n\r\n重量：350g\r\n材質：金屬、滌綸、牛津布',
#   'price': 699,
#   'originPrice': 699,
#   'author': '',
#   'brand': '',
#   'publishDate': '',
#   'sellerId': '',
#   'isPChome': 1,
#   'isNC17': 0,
#   'couponActid': [],
#   'BU': 'ec'},
#  {'Id': 'DIBMWU-A90089I4Q',
#   'cateId': 'DIBMZZ',
#   'picS': '/items/DIBMWUA90089I4Q/000001_1594001989.jpg',
#   'picB': '/items/DIBMWUA90089I4Q/000001_1594001989.jpg',
#   'name': '防磁防射頻盜錄RFID男士錢包',
#   'describe': '防磁防射頻盜錄RFID錢包\\r\\nrfid防磁防射頻識別無從側錄出行安心！',
#   'price': 399,
#   'originPrice': 399,
#   'author': '',
# ...

# %%
goods[10]["name"]
# Out:
# 'Coach男用零錢包短夾C字浮雕logo黑'

# %%
goods[10]['price']
# Out:
# 3280

# %%
json_content['totalPage']
# Out:
# 100

# %%
json_content
# Out:
# {'QTime': 33,
#  'totalRows': 8615,
#  'totalPage': 100,
#  'range': {'min': '', 'max': ''},
#  'cateName': '',
#  'q': '錢包',
#  'subq': '',
#  'token': ['錢包', '錢', '包'],
#  'isMust': 1,
#  'prods': [{'Id': 'DIBMAR-A90095EBR',
#    'cateId': 'DIBMW2',
#    'picS': '/items/DIBMARA90095EBR/000002_1548301485.jpg',
#    'picB': '/items/DIBMARA90095EBR/000001_1548301485.jpg',
#    'name': 'KAKA 韓系簡約長夾 皮夾 手拿包 手機包 零錢包 長皮包',
#    'describe': 'KAKA 韓系簡約長夾 皮夾 手拿包 手機包 零錢包 長皮包 信用卡夾\\r\\n◆ 多夾層、大容量可裝入5.5吋手機\r\n◆ 鈔票位x3、卡片位x3、拉鍊袋x3、收據夾層x2\r\n◆ 耐磨布料，質感極佳\r\n◆ 拉鍊設計，使用方便\r\n◆ 超實搭配件\r\n\r\n  外觀尺寸  \r\n約高21cm，寬10cm，厚度2.5cm\r\n(尺寸皆為人工測量，可能有1-2cm的誤差)\r\n\r\n重量：350g\r\n材質：金屬、滌綸、牛津布',
#    'price': 699,
#    'originPrice': 699,
#    'author': '',
#    'brand': '',
#    'publishDate': '',
#    'sellerId': '',
#    'isPChome': 1,
#    'isNC17': 0,
#    'couponActid': [],
#    'BU': 'ec'},
#   {'Id': 'DIBMWU-A90089I4Q',
#    'cateId': 'DIBMZZ',
#    'picS': '/items/DIBMWUA90089I4Q/000001_1594001989.jpg',
# ...

# %%
len(goods)
# Out:
# 20
